# %% [markdown]
# # 旧版爬虫(臃肿无效)

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from bs4 import BeautifulSoup, NavigableString, Tag
from urllib.parse import urljoin, urlparse
import concurrent.futures
import threading
import logging
import json
import os
from tqdm.notebook import tqdm
import time

# --- 配置 ---
START_URL = "https://webpath.med.utah.edu/ORGAN.html"
OUTPUT_FILE = "webpath_system_path_archive.json"
MAX_WORKERS = 30
RETRY_COUNT = 3
RETRY_BACKOFF = 0.5

# --- 日志配置 ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(threadName)s - %(levelname)s - %(message)s')

# --- 线程安全的数据结构 ---
# 这个集合将包含所有已知URL(无论成功失败)，用于防止重复添加任务
all_known_urls = set() 
# 这个列表只存储本次运行产生的新结果
current_run_results = []
# 统一的锁
lock = threading.Lock()

# --- 核心功能函数 (与之前版本相同) ---
def setup_session_with_retries():
    """创建一个带有自动重试功能和自定义连接池大小的requests Session对象"""
    session = requests.Session()
    
    # 1. 定义重试策略
    retry_strategy = Retry(
        total=RETRY_COUNT,
        backoff_factor=RETRY_BACKOFF,
        status_forcelist=[500, 502, 503, 504],
        allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    
    # 2. 创建一个适配器 (Adapter)，并在这里配置连接池！
    #    pool_connections: 控制连接池的总数 (通常设为与workers数一致即可)
    #    pool_maxsize: 控制每个连接池中的最大连接数。这是解决问题的关键！
    adapter = HTTPAdapter(
        pool_connections=MAX_WORKERS, 
        pool_maxsize=MAX_WORKERS, 
        max_retries=retry_strategy
    )
    
    # 3. 将配置好的适配器挂载到session上
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    
    # 4. 设置浏览器User-Agent
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    })
    
    return session

def html_to_json_structure(element):
    if isinstance(element, NavigableString):
        text = element.strip()
        return text if text else None
    if isinstance(element, Tag):
        obj = {"tag": element.name, "attrs": element.attrs, "children": []}
        for child in element.contents:
            child_json = html_to_json_structure(child)
            if child_json: obj["children"].append(child_json)
        if not obj["children"]: del obj["children"]
        return obj
    return None

# --- 断点续爬的核心逻辑 ---
def load_and_prepare_state():
    """
    加载本地JSON文件，分离出成功的、失败的，并准备续爬任务。
    返回:
        - tasks_to_retry (set): 需要重新爬取的URL集合。
        - successful_data (dict): {url: data} 形式的、已成功爬取的数据字典。
    """
    if not os.path.exists(OUTPUT_FILE):
        logging.info(f"No previous data file found. Starting a new crawl.")
        return set(), {}
        
    logging.info(f"Found existing data file '{OUTPUT_FILE}'. Loading state...")
    try:
        with open(OUTPUT_FILE, 'r', encoding='utf-8') as f:
            previous_data = json.load(f)
        
        tasks_to_retry = set()
        successful_data = {}
        
        for item in previous_data:
            url = item.get('url')
            if not url: continue
            
            # 记录所有已知的URL
            all_known_urls.add(url)
            
            # 分类：失败的进重试队列，成功的进保留字典
            if item.get('status_code') == 'Error' or item.get('error'):
                tasks_to_retry.add(url)
            else:
                successful_data[url] = item
        
        logging.info(f"Loaded {len(all_known_urls)} known URLs. "
                     f"Found {len(successful_data)} successful pages and {len(tasks_to_retry)} pages to retry.")
        return tasks_to_retry, successful_data
        
    except (IOError, json.JSONDecodeError) as e:
        logging.error(f"Could not load or parse previous data file: {e}. Starting fresh.")
        return set(), {}

def crawl_page(url, session):
    """爬取单个页面，逻辑与之前基本一致"""
    try:
        logging.info(f"Processing -> {url}")
        response = session.get(url, timeout=15)
        response.raise_for_status()

        page_data = {
            'url': url, 'status_code': response.status_code,
            'content_type': response.headers.get('content-type', '').lower(),
            'crawl_timestamp': time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime()),
            'is_leaf_node': True, 'html_structure': None, 'error': None
        }

        new_urls_to_crawl = []
        if 'text/html' in page_data['content_type']:
            soup = BeautifulSoup(response.text, 'html.parser')
            page_data['html_structure'] = html_to_json_structure(soup)
            
            base_domain = urlparse(START_URL).netloc
            for link in soup.find_all('a', href=True):
                absolute_url = urljoin(url, link['href']).split('#')[0]
                if urlparse(absolute_url).netloc == base_domain:
                    new_urls_to_crawl.append(absolute_url)
        
        # 判断是否为叶子节点 (检查新链接是否全都是已知链接)
        if any(u not in all_known_urls for u in new_urls_to_crawl):
            page_data['is_leaf_node'] = False

    except requests.RequestException as e:
        logging.error(f"Failed to fetch {url} after retries: {e}")
        page_data = {
            'url': url, 'status_code': 'Error', 'error': str(e),
            'crawl_timestamp': time.strftime('%Y-%m-%dT%H:%M:%SZ', time.gmtime())
        }
        new_urls_to_crawl = []

    with lock:
        current_run_results.append(page_data)
        
    return new_urls_to_crawl

# --- 主执行逻辑 ---
def main():
    start_time = time.time()
    
    # 1. 加载旧状态，并准备初始任务
    tasks_to_retry, successful_data = load_and_prepare_state()
    tasks_queue = set(tasks_to_retry)
    
    # 如果起始URL从未被处理过，则加入任务队列
    if START_URL not in all_known_urls:
        tasks_queue.add(START_URL)

    if not tasks_queue:
        logging.info("No new or failed URLs to process. Exiting.")
        return

    session = setup_session_with_retries()
    
    # 2. 使用线程池进行并发处理
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        with tqdm(total=len(tasks_queue), desc="Processing Pages") as pbar:
            while tasks_queue:
                future_to_url = {executor.submit(crawl_page, url, session): url for url in tasks_queue}
                tasks_queue.clear() # 清空当前批次
                
                for future in concurrent.futures.as_completed(future_to_url):
                    pbar.update(1)
                    new_links = future.result()
                    
                    with lock:
                        for link in new_links:
                            if link not in all_known_urls:
                                all_known_urls.add(link)
                                tasks_queue.add(link)
                                pbar.total += 1 # 动态增加进度条
        
    logging.info(f"Crawl finished for this session. Processed {len(current_run_results)} pages.")

    # 3. 合并新旧数据并保存
    logging.info(f"Merging new results with {len(successful_data)} previously successful pages...")
    
    # 将本次运行的结果也变成一个字典，方便合并
    # 如果一个URL被重试成功，新结果会覆盖旧的失败记录
    for item in current_run_results:
        successful_data[item['url']] = item

    # 将合并后的字典的值转换为列表，准备写入文件
    final_data = list(successful_data.values())
    
    logging.info(f"Total pages in archive: {len(final_data)}. Saving to {OUTPUT_FILE}...")
    try:
        with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(final_data, f, indent=2, ensure_ascii=False)
        logging.info("Successfully updated data file.")
    except IOError as e:
        logging.error(f"Failed to save file: {e}")

    end_time = time.time()
    print("-" * 50)
    print(f"Total time for this session: {end_time - start_time:.2f} seconds")
    print(f"Total pages in final archive: {len(final_data)}")
    print(f"Data saved to: {OUTPUT_FILE}")
    print("-" * 50)

# --- 运行主函数 ---
main()
# Out:
# 2025-10-26 01:57:36,037 - MainThread - INFO - No previous data file found. Starting a new crawl.
# Processing Pages:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-10-26 01:57:36,065 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/ORGAN.html
# 2025-10-26 01:57:36,902 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEMEIDX.html
# 2025-10-26 01:57:36,902 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNGIDX.html
# 2025-10-26 01:57:36,902 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNSIDX.html
# 2025-10-26 01:57:36,903 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GIIDX.html
# 2025-10-26 01:57:36,903 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALEIDX.html
# 2025-10-26 01:57:36,903 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENALIDX.html
# 2025-10-26 01:57:36,903 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEMIDX.html
# 2025-10-26 01:57:36,903 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDOIDX.html
# 2025-10-26 01:57:36,904 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CVIDX.html
# 2025-10-26 01:57:36,906 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVERIDX.html
# 2025-10-26 01:57:36,906 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/webpath.html
# 2025-10-26 01:57:38,241 - ThreadPoolExecutor-0_10 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:38,246 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME020.html
# 2025-10-26 01:57:38,246 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO026.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG503.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL108.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV125.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM060.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL104.html
# 2025-10-26 01:57:38,247 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS028.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME120.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER064.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO011.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER052.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV095.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM063.html
# 2025-10-26 01:57:38,249 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL087.html
# 2025-10-26 01:57:38,250 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME036.html
# 2025-10-26 01:57:38,250 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV180.html
# 2025-10-26 01:57:38,251 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM059.html
# 2025-10-26 01:57:38,252 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO076.html
# 2025-10-26 01:57:38,252 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER035.html
# 2025-10-26 01:57:38,253 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER022.html
# 2025-10-26 01:57:38,253 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL052.html
# 2025-10-26 01:57:38,253 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER029.html
# 2025-10-26 01:57:38,254 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS026.html
# 2025-10-26 01:57:38,254 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG024.html
# 2025-10-26 01:57:38,255 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME063.html
# 2025-10-26 01:57:38,255 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/PERI177.html
# 2025-10-26 01:57:38,255 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG138.html
# 2025-10-26 01:57:38,256 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM077.html
# 2025-10-26 01:57:38,257 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI002.html
# 2025-10-26 01:57:39,776 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER065.html
# 2025-10-26 01:57:39,786 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM146.html
# 2025-10-26 01:57:39,831 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI167.html
# 2025-10-26 01:57:39,840 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV164.html
# 2025-10-26 01:57:39,845 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/SKIN117.html
# 2025-10-26 01:57:39,869 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG119.html
# 2025-10-26 01:57:40,045 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO002.html
# 2025-10-26 01:57:40,301 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL036.html
# 2025-10-26 01:57:40,313 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL089.html
# 2025-10-26 01:57:40,388 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME016.html
# 2025-10-26 01:57:40,418 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV085.html
# 2025-10-26 01:57:40,466 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS086.html
# 2025-10-26 01:57:40,469 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG010.html
# 2025-10-26 01:57:40,567 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI008.html
# 2025-10-26 01:57:40,572 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI057.html
# 2025-10-26 01:57:40,574 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL093.html
# 2025-10-26 01:57:40,575 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS035.html
# 2025-10-26 01:57:40,575 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV091.html
# 2025-10-26 01:57:40,762 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME154.html
# 2025-10-26 01:57:40,763 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME011.html
# 2025-10-26 01:57:40,777 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL028.html
# 2025-10-26 01:57:40,820 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI134.html
# 2025-10-26 01:57:40,826 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG068.html
# 2025-10-26 01:57:40,862 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS038.html
# 2025-10-26 01:57:40,890 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS136.html
# 2025-10-26 01:57:40,893 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG047.html
# 2025-10-26 01:57:40,928 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS150.html
# 2025-10-26 01:57:40,940 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG182.html
# 2025-10-26 01:57:41,091 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI118.html
# 2025-10-26 01:57:41,093 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG045.html
# 2025-10-26 01:57:43,715 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL032.html
# 2025-10-26 01:57:45,583 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME081.html
# 2025-10-26 01:57:45,603 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG040.html
# 2025-10-26 01:57:45,621 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER059.html
# 2025-10-26 01:57:45,624 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM003.html
# 2025-10-26 01:57:45,652 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL054.html
# 2025-10-26 01:57:45,656 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL055.html
# 2025-10-26 01:57:45,660 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS138.html
# 2025-10-26 01:57:45,662 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL053.html
# 2025-10-26 01:57:45,742 - ThreadPoolExecutor-0_0 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,746 - ThreadPoolExecutor-0_6 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,749 - ThreadPoolExecutor-0_2 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,751 - ThreadPoolExecutor-0_3 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,751 - ThreadPoolExecutor-0_10 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,752 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI006.html
# 2025-10-26 01:57:45,755 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG069.html
# 2025-10-26 01:57:45,756 - ThreadPoolExecutor-0_23 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,760 - ThreadPoolExecutor-0_25 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,763 - ThreadPoolExecutor-0_12 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,766 - ThreadPoolExecutor-0_26 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,770 - ThreadPoolExecutor-0_24 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,771 - ThreadPoolExecutor-0_11 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,836 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS088.html
# 2025-10-26 01:57:45,860 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV045.html
# 2025-10-26 01:57:45,862 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV146.html
# 2025-10-26 01:57:45,864 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG014.html
# 2025-10-26 01:57:45,865 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO019.html
# 2025-10-26 01:57:45,872 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI152.html
# 2025-10-26 01:57:45,874 - ThreadPoolExecutor-0_8 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 01:57:45,914 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER074.html
# 2025-10-26 01:57:45,920 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME026.html
# 2025-10-26 01:57:45,931 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE134.html
# 2025-10-26 01:57:45,941 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM016.html
# 2025-10-26 01:57:45,946 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/BLAD062.html
# 2025-10-26 01:57:45,971 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL063.html
# 2025-10-26 01:57:45,980 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/PERI019.html
# 2025-10-26 01:57:45,993 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM054.html
# 2025-10-26 01:57:46,003 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/PERI217.html
# 2025-10-26 01:57:46,022 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER012.html
# 2025-10-26 01:57:46,040 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER083.html
# 2025-10-26 01:57:46,053 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI030.html
# 2025-10-26 01:57:46,132 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO014.html
# 2025-10-26 01:57:46,527 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME108.html
# 2025-10-26 01:57:46,596 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG185.html
# 2025-10-26 01:57:46,616 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV032.html
# 2025-10-26 01:57:46,631 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER040.html
# 2025-10-26 01:57:46,684 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM035.html
# 2025-10-26 01:57:46,685 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG062.html
# 2025-10-26 01:57:46,860 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO039.html
# 2025-10-26 01:57:46,864 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER009.html
# 2025-10-26 01:57:46,865 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV177.html
# 2025-10-26 01:57:46,869 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG018.html
# 2025-10-26 01:57:46,871 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM053.html
# 2025-10-26 01:57:52,116 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV080.html
# 2025-10-26 01:57:52,122 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI016.html
# 2025-10-26 01:57:52,128 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG075.html
# 2025-10-26 01:57:52,171 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM083.html
# 2025-10-26 01:57:52,171 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV016.html
# 2025-10-26 01:57:52,286 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL148.html
# 2025-10-26 01:57:52,316 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL098.html
# 2025-10-26 01:57:52,374 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI071.html
# 2025-10-26 01:57:52,379 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME039.html
# 2025-10-26 01:57:52,390 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE117.html
# 2025-10-26 01:57:52,393 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO046.html
# 2025-10-26 01:57:52,429 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS048.html
# 2025-10-26 01:57:52,432 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG080.html
# 2025-10-26 01:57:52,503 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM080.html
# 2025-10-26 01:57:52,504 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS097.html
# 2025-10-26 01:57:52,511 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI126.html
# 2025-10-26 01:57:52,629 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV073.html
# 2025-10-26 01:57:52,631 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI184.html
# 2025-10-26 01:57:52,636 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS018.html
# 2025-10-26 01:57:52,637 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/EXAM/EXAMIDX.html
# 2025-10-26 01:57:52,638 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG133.html
# 2025-10-26 01:57:52,641 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS070.html
# 2025-10-26 01:57:52,865 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM029.html
# 2025-10-26 01:57:52,897 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME085.html
# 2025-10-26 01:57:52,900 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM004.html
# 2025-10-26 01:57:52,904 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL021.html
# 2025-10-26 01:57:52,904 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME152.html
# 2025-10-26 01:57:53,153 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER013.html
# 2025-10-26 01:57:53,155 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM022.html
# 2025-10-26 01:57:53,158 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV017.html
# 2025-10-26 01:57:53,159 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV024.html
# 2025-10-26 01:57:53,183 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV123.html
# 2025-10-26 01:57:53,421 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS081.html
# 2025-10-26 01:57:53,681 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV067.html
# 2025-10-26 01:57:53,684 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM039.html
# 2025-10-26 01:57:53,684 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO111.html
# 2025-10-26 01:57:53,754 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO115.html
# 2025-10-26 01:57:53,808 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE075.html
# 2025-10-26 01:57:54,017 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI112.html
# 2025-10-26 01:57:54,019 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS178.html
# 2025-10-26 01:57:54,095 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS098.html
# 2025-10-26 01:57:54,212 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER001.html
# 2025-10-26 01:57:54,280 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI117.html
# 2025-10-26 01:57:54,282 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG030.html
# 2025-10-26 01:57:54,394 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL039.html
# 2025-10-26 01:57:54,457 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM122.html
# 2025-10-26 01:57:54,476 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV326.html
# 2025-10-26 01:57:54,512 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER005.html
# 2025-10-26 01:57:54,540 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI190.html
# 2025-10-26 01:57:54,575 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV107.html
# 2025-10-26 01:57:54,632 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV029.html
# 2025-10-26 01:57:54,823 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL102.html
# 2025-10-26 01:57:54,919 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS042.html
# 2025-10-26 01:57:54,920 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER051.html
# 2025-10-26 01:57:55,512 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM078.html
# 2025-10-26 01:57:55,776 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM048.html
# 2025-10-26 01:57:58,956 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME027.html
# 2025-10-26 01:57:59,023 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME013.html
# 2025-10-26 01:57:59,027 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO023.html
# 2025-10-26 01:57:59,040 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER034.html
# 2025-10-26 01:57:59,165 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI013.html
# 2025-10-26 01:57:59,168 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO035.html
# 2025-10-26 01:57:59,192 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL057.html
# 2025-10-26 01:57:59,194 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV076.html
# 2025-10-26 01:57:59,289 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/BLAD060.html
# 2025-10-26 01:57:59,448 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME015.html
# 2025-10-26 01:57:59,452 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER017.html
# 2025-10-26 01:57:59,454 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG158.html
# 2025-10-26 01:57:59,462 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME127.html
# 2025-10-26 01:57:59,471 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV140.html
# 2025-10-26 01:57:59,489 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS037.html
# 2025-10-26 01:57:59,500 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI208.html
# 2025-10-26 01:57:59,638 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI059.html
# 2025-10-26 01:57:59,690 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM019.html
# 2025-10-26 01:57:59,708 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI440.html
# 2025-10-26 01:57:59,714 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG049.html
# 2025-10-26 01:57:59,761 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV014.html
# 2025-10-26 01:57:59,813 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER014.html
# 2025-10-26 01:58:00,030 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM095.html
# 2025-10-26 01:58:00,037 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE065.html
# 2025-10-26 01:58:00,064 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV179.html
# 2025-10-26 01:58:00,162 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV103.html
# 2025-10-26 01:58:00,234 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG008.html
# 2025-10-26 01:58:00,316 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV151.html
# 2025-10-26 01:58:00,509 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG016.html
# 2025-10-26 01:58:00,524 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI077.html
# 2025-10-26 01:58:00,557 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO034.html
# 2025-10-26 01:58:00,576 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL058.html
# 2025-10-26 01:58:00,857 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG035.html
# 2025-10-26 01:58:01,023 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER045.html
# 2025-10-26 01:58:01,026 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI500.html
# 2025-10-26 01:58:01,032 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM125.html
# 2025-10-26 01:58:01,033 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG079.html
# 2025-10-26 01:58:01,034 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS031.html
# 2025-10-26 01:58:01,211 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS400.html
# 2025-10-26 01:58:01,216 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER061.html
# 2025-10-26 01:58:01,217 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL043.html
# 2025-10-26 01:58:01,220 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER047.html
# 2025-10-26 01:58:01,292 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL094.html
# 2025-10-26 01:58:01,543 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG127.html
# 2025-10-26 01:58:01,735 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI073.html
# 2025-10-26 01:58:01,737 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO043.html
# 2025-10-26 01:58:05,764 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS144.html
# 2025-10-26 01:58:06,016 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS058.html
# 2025-10-26 01:58:06,026 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI058.html
# 2025-10-26 01:58:06,032 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME017.html
# 2025-10-26 01:58:06,041 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER008.html
# 2025-10-26 01:58:06,133 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS055.html
# 2025-10-26 01:58:06,141 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI027.html
# 2025-10-26 01:58:06,261 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL045.html
# 2025-10-26 01:58:06,560 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE095.html
# 2025-10-26 01:58:06,786 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE089.html
# 2025-10-26 01:58:06,960 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV126.html
# 2025-10-26 01:58:07,039 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG085.html
# 2025-10-26 01:58:07,064 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM047.html
# 2025-10-26 01:58:07,152 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM036.html
# 2025-10-26 01:58:07,180 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG058.html
# 2025-10-26 01:58:07,419 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO009.html
# 2025-10-26 01:58:07,559 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG142.html
# 2025-10-26 01:58:07,562 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS093.html
# 2025-10-26 01:58:07,645 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME025.html
# 2025-10-26 01:58:07,726 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG074.html
# 2025-10-26 01:58:07,837 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL046.html
# 2025-10-26 01:58:07,839 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI005.html
# 2025-10-26 01:58:07,886 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI084.html
# 2025-10-26 01:58:07,925 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS092.html
# 2025-10-26 01:58:07,969 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO037.html
# 2025-10-26 01:58:08,229 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI044.html
# 2025-10-26 01:58:10,608 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG125.html
# 2025-10-26 01:58:10,612 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS060.html
# 2025-10-26 01:58:10,615 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM015.html
# 2025-10-26 01:58:10,623 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI009.html
# 2025-10-26 01:58:11,917 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS072.html
# 2025-10-26 01:58:12,027 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL031.html
# 2025-10-26 01:58:12,032 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL050.html
# 2025-10-26 01:58:12,038 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS123.html
# 2025-10-26 01:58:12,040 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM072.html
# 2025-10-26 01:58:12,043 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/DIABETES/DIABETES.html
# 2025-10-26 01:58:12,046 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI067.html
# 2025-10-26 01:58:12,047 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI168.html
# 2025-10-26 01:58:12,065 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL084.html
# 2025-10-26 01:58:12,115 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS112.html
# 2025-10-26 01:58:12,290 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG505.html
# 2025-10-26 01:58:12,305 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME004.html
# 2025-10-26 01:58:12,309 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL086.html
# 2025-10-26 01:58:12,343 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER037.html
# 2025-10-26 01:58:12,353 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI177.html
# 2025-10-26 01:58:12,378 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL018.html
# 2025-10-26 01:58:12,394 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME032.html
# 2025-10-26 01:58:12,438 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI014.html
# 2025-10-26 01:58:12,457 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI019.html
# 2025-10-26 01:58:12,826 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI022.html
# 2025-10-26 01:58:12,832 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS099.html
# 2025-10-26 01:58:12,843 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME018.html
# 2025-10-26 01:58:12,871 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL109.html
# 2025-10-26 01:58:12,876 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO044.html
# 2025-10-26 01:58:12,901 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM027.html
# 2025-10-26 01:58:12,913 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG168.html
# 2025-10-26 01:58:12,915 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM009.html
# 2025-10-26 01:58:12,919 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI061.html
# 2025-10-26 01:58:12,922 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG134.html
# 2025-10-26 01:58:12,943 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI209.html
# 2025-10-26 01:58:12,947 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM041.html
# 2025-10-26 01:58:12,950 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS025.html
# 2025-10-26 01:58:12,985 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS121.html
# 2025-10-26 01:58:13,078 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE073.html
# 2025-10-26 01:58:13,346 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO052.html
# 2025-10-26 01:58:13,421 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI186.html
# 2025-10-26 01:58:13,482 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE079.html
# 2025-10-26 01:58:13,603 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS051.html
# 2025-10-26 01:58:13,640 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO005.html
# 2025-10-26 01:58:13,696 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV182.html
# 2025-10-26 01:58:13,748 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL048.html
# 2025-10-26 01:58:13,810 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER030.html
# 2025-10-26 01:58:16,062 - ThreadPoolExecutor-0_6 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /LUNGHTML/LUNG079.html
# 2025-10-26 01:58:16,747 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS033.html
# 2025-10-26 01:58:16,763 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS056.html
# 2025-10-26 01:58:18,636 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME019.html
# 2025-10-26 01:58:18,769 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME037.html
# 2025-10-26 01:58:18,788 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER032.html
# 2025-10-26 01:58:18,810 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/RENAL107.html
# 2025-10-26 01:58:18,813 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM008.html
# 2025-10-26 01:58:18,956 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG143.html
# 2025-10-26 01:58:18,985 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME084.html
# 2025-10-26 01:58:19,209 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS104.html
# 2025-10-26 01:58:19,215 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG096.html
# 2025-10-26 01:58:19,226 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG087.html
# 2025-10-26 01:58:19,273 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL040.html
# 2025-10-26 01:58:19,274 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER025.html
# 2025-10-26 01:58:19,291 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV008.html
# 2025-10-26 01:58:19,293 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV054.html
# 2025-10-26 01:58:19,324 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV082.html
# 2025-10-26 01:58:19,326 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER044.html
# 2025-10-26 01:58:19,358 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE091.html
# 2025-10-26 01:58:19,426 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL010.html
# 2025-10-26 01:58:19,489 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/BLAD058.html
# 2025-10-26 01:58:19,496 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL116.html
# 2025-10-26 01:58:19,530 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI121.html
# 2025-10-26 01:58:19,549 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE102.html
# 2025-10-26 01:58:19,559 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS102.html
# 2025-10-26 01:58:19,563 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL006.html
# 2025-10-26 01:58:19,572 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV047.html
# 2025-10-26 01:58:19,675 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV086.html
# 2025-10-26 01:58:21,062 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/LIVEHTML/LIVER020.html
# 2025-10-26 01:58:21,407 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI056.html
# 2025-10-26 01:58:21,430 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM025.html
# 2025-10-26 01:58:21,955 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG097.html
# 2025-10-26 01:58:29,404 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO048.html
# 2025-10-26 01:58:29,442 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS352.html
# 2025-10-26 01:58:29,443 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE071.html
# 2025-10-26 01:58:29,445 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV124.html
# 2025-10-26 01:58:29,447 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE099.html
# 2025-10-26 01:58:29,558 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV102.html
# 2025-10-26 01:58:29,659 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL005.html
# 2025-10-26 01:58:29,724 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM076.html
# 2025-10-26 01:58:29,808 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG028.html
# 2025-10-26 01:58:29,875 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/MALEHTML/MALE092.html
# 2025-10-26 01:58:29,939 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI194.html
# 2025-10-26 01:58:29,946 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV005.html
# 2025-10-26 01:58:30,086 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV166.html
# 2025-10-26 01:58:30,313 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG500.html
# 2025-10-26 01:58:30,462 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS078.html
# 2025-10-26 01:58:30,471 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL014.html
# 2025-10-26 01:58:30,517 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI028.html
# 2025-10-26 01:58:30,529 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM011.html
# 2025-10-26 01:58:30,533 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV049.html
# 2025-10-26 01:58:30,548 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM045.html
# 2025-10-26 01:58:30,549 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS094.html
# 2025-10-26 01:58:30,580 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI139.html
# 2025-10-26 01:58:30,609 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL012.html
# 2025-10-26 01:58:30,697 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO032.html
# 2025-10-26 01:58:30,710 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV038.html
# 2025-10-26 01:58:30,765 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI011.html
# 2025-10-26 01:58:30,900 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO040.html
# 2025-10-26 01:58:31,119 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV071.html
# 2025-10-26 01:58:31,126 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/RENCYST/RENCYST.html
# 2025-10-26 01:58:31,127 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG090.html
# 2025-10-26 01:58:31,130 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/BLAD063.html
# 2025-10-26 01:58:31,251 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG043.html
# 2025-10-26 01:58:32,010 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV041.html
# 2025-10-26 01:58:33,703 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI024.html
# 2025-10-26 01:58:35,344 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME069.html
# 2025-10-26 01:58:35,351 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/HISTO.html
# 2025-10-26 01:58:35,359 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL120.html
# 2025-10-26 01:58:35,399 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI113.html
# 2025-10-26 01:58:35,401 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL123.html
# 2025-10-26 01:58:35,404 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS032.html
# 2025-10-26 01:58:35,408 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG078.html
# 2025-10-26 01:58:35,454 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/ENDOHTML/ENDO091.html
# 2025-10-26 01:58:35,471 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI068.html
# 2025-10-26 01:58:35,477 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS180.html
# 2025-10-26 01:58:35,571 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/RENAHTML/RENAL090.html
# 2025-10-26 01:58:35,631 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/CVHTML/CV169.html
# 2025-10-26 01:58:35,638 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/GIHTML/GI192.html
# 2025-10-26 01:58:35,645 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS046.html
# 2025-10-26 01:58:35,683 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/CNSHTML/CNS022.html
# 2025-10-26 01:58:35,704 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/FEMHTML/FEM115.html
# 2025-10-26 01:58:35,737 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/LUNGHTML/LUNG033.html
# 2025-10-26 01:58:35,774 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/HEMEHTML/HEME043.html
# ...
# 2025-10-26 02:07:15,139 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN012.html
# 2025-10-26 02:07:15,139 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL04.html
# 2025-10-26 02:07:15,878 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat01frm.htm
# 2025-10-26 02:07:15,912 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat04frm.htm
# 2025-10-26 02:07:15,913 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIFS06.html
# 2025-10-26 02:07:15,926 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIT1C17.html
# 2025-10-26 02:07:15,932 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC09.html
# 2025-10-26 02:07:15,945 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC14.html
# 2025-10-26 02:07:15,970 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIT2A36.html
# 2025-10-26 02:07:15,971 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC03.html
# 2025-10-26 02:07:15,976 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat06frm.htm
# 2025-10-26 02:07:15,982 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat08frm.htm
# 2025-10-26 02:07:15,990 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIFS14.html
# 2025-10-26 02:07:16,081 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat02frm.htm
# 2025-10-26 02:07:16,132 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC08.html
# 2025-10-26 02:07:16,132 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL15.html
# 2025-10-26 02:07:16,142 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC07.html
# 2025-10-26 02:07:16,144 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat07frm.htm
# 2025-10-26 02:07:16,150 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN006.html
# 2025-10-26 02:07:16,151 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat16frm.htm
# 2025-10-26 02:07:16,158 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIFS02.html
# 2025-10-26 02:07:16,159 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC16.html
# 2025-10-26 02:07:16,160 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC06.html
# 2025-10-26 02:07:16,162 - ThreadPoolExecutor-0_13 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:16,197 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL17.html
# 2025-10-26 02:07:16,210 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat03frm.htm
# 2025-10-26 02:07:16,426 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat12frm.htm
# 2025-10-26 02:07:16,480 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL06.html
# 2025-10-26 02:07:16,494 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN002.html
# 2025-10-26 02:07:16,497 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat18frm.htm
# 2025-10-26 02:07:16,588 - ThreadPoolExecutor-0_11 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL14.html
# 2025-10-26 02:07:16,616 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL13.html
# 2025-10-26 02:07:16,629 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL09.html
# 2025-10-26 02:07:16,669 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN003.html
# 2025-10-26 02:07:16,699 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat14frm.htm
# 2025-10-26 02:07:16,751 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL18.html
# 2025-10-26 02:07:16,771 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat13frm.htm
# 2025-10-26 02:07:16,788 - ThreadPoolExecutor-0_3 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/VHF2220R.html
# 2025-10-26 02:07:16,822 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC13.html
# 2025-10-26 02:07:16,823 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC11.html
# 2025-10-26 02:07:16,855 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat10frm.htm
# 2025-10-26 02:07:16,880 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN005.html
# 2025-10-26 02:07:16,953 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORMAL11.html
# 2025-10-26 02:07:16,970 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN004.html
# 2025-10-26 02:07:17,015 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC02.html
# 2025-10-26 02:07:17,020 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat11frm.htm
# 2025-10-26 02:07:17,037 - ThreadPoolExecutor-0_12 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC05.html
# 2025-10-26 02:07:17,058 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat09frm.htm
# 2025-10-26 02:07:17,098 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat15frm.htm
# 2025-10-26 02:07:17,132 - ThreadPoolExecutor-0_9 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/ANATOMY/ANATQUIZ/anat05frm.htm
# 2025-10-26 02:07:17,146 - ThreadPoolExecutor-0_7 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC12.html
# 2025-10-26 02:07:17,229 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN014.html
# 2025-10-26 02:07:17,239 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/HCC/HCC18.html
# 2025-10-26 02:07:17,249 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIFS34.html
# 2025-10-26 02:07:17,368 - ThreadPoolExecutor-0_28 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NEURANAT/MRIT1C12.html
# 2025-10-26 02:07:17,430 - ThreadPoolExecutor-0_19 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN011.html
# 2025-10-26 02:07:17,431 - ThreadPoolExecutor-0_8 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/BLDBANK/BBPROC08.html
# 2025-10-26 02:07:17,434 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/TUTORIAL/GUNS/GUN015.html
# 2025-10-26 02:07:17,822 - ThreadPoolExecutor-0_20 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,840 - ThreadPoolExecutor-0_26 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,842 - ThreadPoolExecutor-0_13 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,858 - ThreadPoolExecutor-0_14 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,919 - ThreadPoolExecutor-0_24 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,927 - ThreadPoolExecutor-0_5 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:17,990 - ThreadPoolExecutor-0_22 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,003 - ThreadPoolExecutor-0_2 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,021 - ThreadPoolExecutor-0_21 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,022 - ThreadPoolExecutor-0_25 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,217 - ThreadPoolExecutor-0_28 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,291 - ThreadPoolExecutor-0_10 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,367 - ThreadPoolExecutor-0_11 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,381 - ThreadPoolExecutor-0_17 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,665 - ThreadPoolExecutor-0_12 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:18,673 - ThreadPoolExecutor-0_3 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:23,947 - ThreadPoolExecutor-0_7 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:23,952 - ThreadPoolExecutor-0_8 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:23,958 - ThreadPoolExecutor-0_9 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:23,962 - ThreadPoolExecutor-0_19 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:23,966 - ThreadPoolExecutor-0_1 - INFO - Processing -> https://webpath.med.utah.edu/GUIDE/WEB03.html
# 2025-10-26 02:07:23,966 - ThreadPoolExecutor-0_18 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX029.html
# 2025-10-26 02:07:23,969 - ThreadPoolExecutor-0_27 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX006.html
# 2025-10-26 02:07:23,969 - ThreadPoolExecutor-0_16 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM192.html
# 2025-10-26 02:07:23,969 - ThreadPoolExecutor-0_6 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX016.html
# 2025-10-26 02:07:23,970 - ThreadPoolExecutor-0_0 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM204.html
# 2025-10-26 02:07:23,970 - ThreadPoolExecutor-0_29 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM191.html
# 2025-10-26 02:07:23,970 - ThreadPoolExecutor-0_4 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX048.html
# 2025-10-26 02:07:23,971 - ThreadPoolExecutor-0_15 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM205.html
# 2025-10-26 02:07:23,971 - ThreadPoolExecutor-0_23 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM198.html
# 2025-10-26 02:07:23,971 - ThreadPoolExecutor-0_20 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM199.html
# 2025-10-26 02:07:23,971 - ThreadPoolExecutor-0_26 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX068.html
# 2025-10-26 02:07:23,972 - ThreadPoolExecutor-0_13 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM194.html
# 2025-10-26 02:07:23,972 - ThreadPoolExecutor-0_14 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM200.html
# 2025-10-26 02:07:23,973 - ThreadPoolExecutor-0_24 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM195.html
# 2025-10-26 02:07:23,973 - ThreadPoolExecutor-0_5 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX017.html
# 2025-10-26 02:07:23,973 - ThreadPoolExecutor-0_22 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM184.html
# 2025-10-26 02:07:23,974 - ThreadPoolExecutor-0_2 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM190.html
# 2025-10-26 02:07:23,975 - ThreadPoolExecutor-0_21 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/NORM201.html
# 2025-10-26 02:07:23,975 - ThreadPoolExecutor-0_25 - INFO - Processing -> https://webpath.med.utah.edu/HISTHTML/NORMAL/IPX035.html
# 2025-10-26 02:07:25,081 - ThreadPoolExecutor-0_22 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,091 - ThreadPoolExecutor-0_21 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,112 - ThreadPoolExecutor-0_2 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,260 - ThreadPoolExecutor-0_27 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,262 - ThreadPoolExecutor-0_23 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,326 - ThreadPoolExecutor-0_0 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,395 - ThreadPoolExecutor-0_26 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,514 - ThreadPoolExecutor-0_14 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,607 - ThreadPoolExecutor-0_24 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,682 - ThreadPoolExecutor-0_1 - WARNING - Connection pool is full, discarding connection: webpath.med.utah.edu. Connection pool size: 10
# 2025-10-26 02:07:25,683 - ThreadPoolExecutor-0_10 - INFO - Processing -> https://webpath.med.utah.edu/CDROM/CDROM.html
# 2025-10-26 02:07:31,414 - ThreadPoolExecutor-0_17 - INFO - Processing -> https://webpath.med.utah.edu/CDROM/orderinsmusm17.pdf
# 2025-10-26 02:07:33,483 - MainThread - INFO - Crawl finished for this session. Processed 3006 pages.
# 2025-10-26 02:07:33,484 - MainThread - INFO - Merging new results with 0 previously successful pages...
# 2025-10-26 02:07:33,489 - MainThread - INFO - Total pages in archive: 3005. Saving to webpath_system_path_archive.json...
# 2025-10-26 02:07:34,845 - MainThread - INFO - Successfully updated data file.
# --------------------------------------------------
# Total time for this session: 598.81 seconds
# Total pages in final archive: 3005
# Data saved to: webpath_system_path_archive.json
# --------------------------------------------------

# %% [markdown]
# # 新版

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from bs4 import BeautifulSoup, NavigableString, Tag
from urllib.parse import urljoin, urlparse
import concurrent.futures
import threading
import logging
import json
import os
from tqdm.notebook import tqdm
import time

# --- 配置 ---
START_URL = "https://webpath.med.utah.edu/ORGAN.html"
OUTPUT_FILE = "webpath_image_data_robust.json" # 新文件名
MAX_WORKERS = 30
RETRY_COUNT = 3
RETRY_BACKOFF = 0.5

# --- 日志配置 ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(threadName)s - %(levelname)s - %(message)s')

# --- 线程安全的数据结构 ---
all_known_urls = set()
current_run_results = []
lock = threading.Lock()

# --- 核心功能函数 ---

def setup_session_with_retries():
    """创建一个带有自动重试和自定义连接池的Session"""
    session = requests.Session()
    retry_strategy = Retry(
        total=RETRY_COUNT, backoff_factor=RETRY_BACKOFF,
        status_forcelist=[500, 502, 503, 504], allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    adapter = HTTPAdapter(pool_connections=MAX_WORKERS, pool_maxsize=MAX_WORKERS, max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    })
    return session

def extract_image_data_robust(html_content, base_url):
    """
    【核心改进】稳健地提取页面中的图片区块。
    一个区块由一张jpeg图片和其后的所有相关描述文本组成。
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    # 如果页面没有body，则直接返回
    body = soup.find('body')
    if not body:
        return []

    records = []
    current_record = None

    # 遍历body标签的所有直接子元素
    for element in body.children:
        if not isinstance(element, Tag):
            continue  # 跳过非标签元素，如换行符

        # 检查是否是一个新的图片区块的开始
        if element.name == 'img' and 'jpeg' in element.get('src', '').lower():
            # 如果我们正在处理上一个区块，先保存它
            if current_record:
                records.append(current_record)
            
            # 开始一个新的区块记录
            current_record = {
                'image_url': urljoin(base_url, element['src']),
                'descriptions': []
            }
        
        # 如果我们已经在一个图片区块内，检查当前元素是否是描述性表格
        elif element.name == 'table' and current_record:
            # 智能判断：如果一个表格包含导航GIF，它就不是描述性表格
            is_navigation_table = element.find('img', src=lambda s: s and '.gif' in s.lower())
            
            if not is_navigation_table:
                description_text = element.get_text(separator=' ', strip=True)
                if description_text:  # 确保不添加空描述
                    current_record['descriptions'].append(description_text)
    
    # 不要忘记保存循环结束后的最后一个区块
    if current_record:
        records.append(current_record)
        
    return records


def load_and_prepare_state():
    """加载本地JSON文件，准备续爬任务 (无变化)"""
    if not os.path.exists(OUTPUT_FILE):
        logging.info("No previous data file found. Starting a new crawl.")
        return set(), {}
    logging.info(f"Found existing data file '{OUTPUT_FILE}'. Loading state...")
    try:
        with open(OUTPUT_FILE, 'r', encoding='utf-8') as f:
            previous_data = json.load(f)
        tasks_to_retry = set()
        successful_data = {}
        for item in previous_data:
            url = item.get('url')
            if not url: continue
            all_known_urls.add(url)
            if item.get('status_code') == 'Error' or item.get('error'):
                tasks_to_retry.add(url)
            else: successful_data[url] = item
        logging.info(f"Loaded {len(all_known_urls)} URLs. Found {len(successful_data)} successful pages and {len(tasks_to_retry)} to retry.")
        return tasks_to_retry, successful_data
    except (IOError, json.JSONDecodeError) as e:
        logging.error(f"Could not load or parse previous data file: {e}. Starting fresh.")
        return set(), {}


def crawl_page(url, session):
    """爬取单个页面，使用稳健的提取逻辑，并返回新链接 (调用新函数)"""
    try:
        response = session.get(url, timeout=15)
        response.raise_for_status()
        html_content = response.text
        
        extracted_items = []
        if 'jpeg' in html_content.lower():
            # 调用新的、更稳健的提取函数
            extracted_items = extract_image_data_robust(html_content, url)

        page_data = {
            'url': url,
            'status_code': response.status_code,
            'extracted_data': extracted_items,
            'error': None
        }

        soup = BeautifulSoup(html_content, 'html.parser')
        new_urls_to_crawl = []
        base_domain = urlparse(START_URL).netloc
        for link in soup.find_all('a', href=True):
            absolute_url = urljoin(url, link['href']).split('#')[0]
            if urlparse(absolute_url).netloc == base_domain:
                new_urls_to_crawl.append(absolute_url)

    except requests.RequestException as e:
        logging.error(f"Failed to fetch {url} after retries: {e}")
        page_data = {'url': url, 'status_code': 'Error', 'error': str(e), 'extracted_data': []}
        new_urls_to_crawl = []

    with lock:
        current_run_results.append(page_data)
        
    return new_urls_to_crawl


# --- 主执行逻辑 (无变化) ---
def main():
    start_time = time.time()
    tasks_to_retry, successful_data = load_and_prepare_state()
    tasks_queue = set(tasks_to_retry)
    if START_URL not in all_known_urls:
        tasks_queue.add(START_URL)

    if not tasks_queue:
        logging.info("No new or failed URLs to process. The data is up-to-date.")
        return

    session = setup_session_with_retries()
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        with tqdm(total=len(tasks_queue), desc="Processing Pages") as pbar:
            while tasks_queue:
                future_to_url = {executor.submit(crawl_page, url, session): url for url in tasks_queue}
                tasks_queue.clear()
                
                for future in concurrent.futures.as_completed(future_to_url):
                    pbar.update(1)
                    new_links = future.result()
                    with lock:
                        for link in new_links:
                            if link not in all_known_urls:
                                all_known_urls.add(link)
                                tasks_queue.add(link)
                                pbar.total += 1
        
    logging.info(f"Crawl finished for this session. Processed {len(current_run_results)} pages.")

    # 合并新旧数据并保存
    logging.info(f"Merging new results with {len(successful_data)} previously processed pages...")
    for item in current_run_results:
        successful_data[item['url']] = item

    final_data = [item for item in successful_data.values() if item.get('extracted_data') or item.get('error')]
    
    logging.info(f"Found {len(final_data)} pages with relevant data or errors. Saving to {OUTPUT_FILE}...")
    try:
        with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(final_data, f, indent=2, ensure_ascii=False)
        logging.info("Successfully updated data file.")
    except IOError as e:
        logging.error(f"Failed to save file: {e}")

    end_time = time.time()
    print("-" * 50)
    print(f"Total time for this session: {end_time - start_time:.2f} seconds")
    print(f"Total pages with data/errors in final archive: {len(final_data)}")
    print(f"Data saved to: {OUTPUT_FILE}")
    print("-" * 50)

# --- 运行主函数 ---
main()
# Out:
# 2025-10-26 02:18:29,639 - MainThread - INFO - No previous data file found. Starting a new crawl.
# Processing Pages:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-10-26 02:18:37,600 - ThreadPoolExecutor-0_27 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /LUNGHTML/LUNG024.html
# 2025-10-26 02:21:25,304 - ThreadPoolExecutor-0_26 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /HISTHTML/STAINS/STAIN003.html
# 2025-10-26 02:22:26,343 - ThreadPoolExecutor-0_21 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /INFLHTML/INFL019.html
# 2025-10-26 02:22:27,055 - ThreadPoolExecutor-0_17 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /PEDHTML/PED228.html
# 2025-10-26 02:22:27,107 - ThreadPoolExecutor-0_7 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /TUTORIAL/AIDS/AIDS044.html
# 2025-10-26 02:22:27,169 - ThreadPoolExecutor-0_18 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /EXAM/REVQUIZ/CLIN02Quiz/index.html
# 2025-10-26 02:22:27,282 - ThreadPoolExecutor-0_27 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /HISTHTML/MANUALS/HORTEGA.PDF
# 2025-10-26 02:22:27,305 - ThreadPoolExecutor-0_10 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /HISTHTML/NORMAL/NORM203.html
# 2025-10-26 02:22:27,365 - ThreadPoolExecutor-0_8 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /HISTHTML/STAINS/STAIN010.html
# 2025-10-26 02:22:27,398 - ThreadPoolExecutor-0_0 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /TUTORIAL/AIDS/AIDS076.html
# 2025-10-26 02:22:27,493 - ThreadPoolExecutor-0_9 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /TUTORIAL/AIDS/AIDS008.html
# 2025-10-26 02:22:27,545 - ThreadPoolExecutor-0_14 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /ATHHTML/ATH024.html
# 2025-10-26 02:22:27,651 - ThreadPoolExecutor-0_26 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /TUTORIAL/PRENATAL/PREN025.html
# 2025-10-26 02:22:27,688 - ThreadPoolExecutor-0_6 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /LABS/EMBRYLAB/EMBRY027.html
# 2025-10-26 02:22:27,754 - ThreadPoolExecutor-0_3 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='webpath.med.utah.edu', port=443): Read timed out. (read timeout=15)")': /TUTORIAL/LEARN/LEARN14.html
# 2025-10-26 02:22:31,205 - ThreadPoolExecutor-0_1 - ERROR - Failed to fetch https://webpath.med.utah.edu/HISTHTML/ANATOMY/anatquiz/quizaidx.htm after retries: 404 Client Error: Not Found for url: https://webpath.med.utah.edu/HISTHTML/ANATOMY/anatquiz/quizaidx.htm
# 2025-10-26 02:22:34,322 - ThreadPoolExecutor-0_26 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')': /HISTHTML/MANUALS/ZIEHL.PDF
# 2025-10-26 02:24:19,809 - MainThread - INFO - Crawl finished for this session. Processed 3006 pages.
# 2025-10-26 02:24:19,811 - MainThread - INFO - Merging new results with 0 previously processed pages...
# 2025-10-26 02:24:19,815 - MainThread - INFO - Found 2389 pages with relevant data or errors. Saving to webpath_image_data_robust.json...
# 2025-10-26 02:24:19,852 - MainThread - INFO - Successfully updated data file.
# --------------------------------------------------
# Total time for this session: 350.21 seconds
# Total pages with data/errors in final archive: 2389
# Data saved to: webpath_image_data_robust.json
# --------------------------------------------------

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from bs4 import BeautifulSoup, NavigableString, Tag
from urllib.parse import urljoin, urlparse
import concurrent.futures
import threading
import logging
import json
import os
from tqdm.notebook import tqdm
import time

# --- 配置 ---
START_URL = "https://webpath.med.utah.edu/ORGAN.html"
OUTPUT_FILE = "webpath_image_data_robust.json" # 新文件名
MAX_WORKERS = 30
RETRY_COUNT = 3
RETRY_BACKOFF = 0.5

# --- 日志配置 ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(threadName)s - %(levelname)s - %(message)s')

# --- 线程安全的数据结构 ---
all_known_urls = set()
current_run_results = []
lock = threading.Lock()

# --- 核心功能函数 ---

def setup_session_with_retries():
    """创建一个带有自动重试和自定义连接池的Session"""
    session = requests.Session()
    retry_strategy = Retry(
        total=RETRY_COUNT, backoff_factor=RETRY_BACKOFF,
        status_forcelist=[500, 502, 503, 504], allowed_methods=["HEAD", "GET", "OPTIONS"]
    )
    adapter = HTTPAdapter(pool_connections=MAX_WORKERS, pool_maxsize=MAX_WORKERS, max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    })
    return session

def extract_image_data_robust(html_content, base_url):
    """
    【核心改进】稳健地提取页面中的图片区块。
    一个区块由一张jpeg图片和其后的所有相关描述文本组成。
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    # 如果页面没有body，则直接返回
    body = soup.find('body')
    if not body:
        return []

    records = []
    current_record = None

    # 遍历body标签的所有直接子元素
    for element in body.children:
        if not isinstance(element, Tag):
            continue  # 跳过非标签元素，如换行符

        # 检查是否是一个新的图片区块的开始
        if element.name == 'img' and 'jpeg' in element.get('src', '').lower():
            # 如果我们正在处理上一个区块，先保存它
            if current_record:
                records.append(current_record)
            
            # 开始一个新的区块记录
            current_record = {
                'image_url': urljoin(base_url, element['src']),
                'descriptions': []
            }
        
        # 如果我们已经在一个图片区块内，检查当前元素是否是描述性表格
        elif element.name == 'table' and current_record:
            # 智能判断：如果一个表格包含导航GIF，它就不是描述性表格
            is_navigation_table = element.find('img', src=lambda s: s and '.gif' in s.lower())
            
            if not is_navigation_table:
                description_text = element.get_text(separator=' ', strip=True)
                if description_text:  # 确保不添加空描述
                    current_record['descriptions'].append(description_text)
    
    # 不要忘记保存循环结束后的最后一个区块
    if current_record:
        records.append(current_record)
        
    return records


def load_and_prepare_state():
    """加载本地JSON文件，准备续爬任务 (无变化)"""
    if not os.path.exists(OUTPUT_FILE):
        logging.info("No previous data file found. Starting a new crawl.")
        return set(), {}
    logging.info(f"Found existing data file '{OUTPUT_FILE}'. Loading state...")
    try:
        with open(OUTPUT_FILE, 'r', encoding='utf-8') as f:
            previous_data = json.load(f)
        tasks_to_retry = set()
        successful_data = {}
        for item in previous_data:
            url = item.get('url')
            if not url: continue
            all_known_urls.add(url)
            if item.get('status_code') == 'Error' or item.get('error'):
                tasks_to_retry.add(url)
            else: successful_data[url] = item
        logging.info(f"Loaded {len(all_known_urls)} URLs. Found {len(successful_data)} successful pages and {len(tasks_to_retry)} to retry.")
        return tasks_to_retry, successful_data
    except (IOError, json.JSONDecodeError) as e:
        logging.error(f"Could not load or parse previous data file: {e}. Starting fresh.")
        return set(), {}


def crawl_page(url, session):
    """爬取单个页面，使用稳健的提取逻辑，并返回新链接 (调用新函数)"""
    try:
        response = session.get(url, timeout=15)
        response.raise_for_status()
        html_content = response.text
        
        extracted_items = []
        if 'jpeg' in html_content.lower():
            # 调用新的、更稳健的提取函数
            extracted_items = extract_image_data_robust(html_content, url)

        page_data = {
            'url': url,
            'status_code': response.status_code,
            'extracted_data': extracted_items,
            'error': None
        }

        soup = BeautifulSoup(html_content, 'html.parser')
        new_urls_to_crawl = []
        base_domain = urlparse(START_URL).netloc
        for link in soup.find_all('a', href=True):
            absolute_url = urljoin(url, link['href']).split('#')[0]
            if urlparse(absolute_url).netloc == base_domain:
                new_urls_to_crawl.append(absolute_url)

    except requests.RequestException as e:
        logging.error(f"Failed to fetch {url} after retries: {e}")
        page_data = {'url': url, 'status_code': 'Error', 'error': str(e), 'extracted_data': []}
        new_urls_to_crawl = []

    with lock:
        current_run_results.append(page_data)
        
    return new_urls_to_crawl


# --- 主执行逻辑 (无变化) ---
def main():
    start_time = time.time()
    tasks_to_retry, successful_data = load_and_prepare_state()
    tasks_queue = set(tasks_to_retry)
    if START_URL not in all_known_urls:
        tasks_queue.add(START_URL)

    if not tasks_queue:
        logging.info("No new or failed URLs to process. The data is up-to-date.")
        return

    session = setup_session_with_retries()
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        with tqdm(total=len(tasks_queue), desc="Processing Pages") as pbar:
            while tasks_queue:
                future_to_url = {executor.submit(crawl_page, url, session): url for url in tasks_queue}
                tasks_queue.clear()
                
                for future in concurrent.futures.as_completed(future_to_url):
                    pbar.update(1)
                    new_links = future.result()
                    with lock:
                        for link in new_links:
                            if link not in all_known_urls:
                                all_known_urls.add(link)
                                tasks_queue.add(link)
                                pbar.total += 1
        
    logging.info(f"Crawl finished for this session. Processed {len(current_run_results)} pages.")

    # 合并新旧数据并保存
    logging.info(f"Merging new results with {len(successful_data)} previously processed pages...")
    for item in current_run_results:
        successful_data[item['url']] = item

    final_data = [item for item in successful_data.values() if item.get('extracted_data') or item.get('error')]
    
    logging.info(f"Found {len(final_data)} pages with relevant data or errors. Saving to {OUTPUT_FILE}...")
    try:
        with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(final_data, f, indent=2, ensure_ascii=False)
        logging.info("Successfully updated data file.")
    except IOError as e:
        logging.error(f"Failed to save file: {e}")

    end_time = time.time()
    print("-" * 50)
    print(f"Total time for this session: {end_time - start_time:.2f} seconds")
    print(f"Total pages with data/errors in final archive: {len(final_data)}")
    print(f"Data saved to: {OUTPUT_FILE}")
    print("-" * 50)

# --- 运行主函数 ---
main()
# Out:
# 2025-10-26 02:28:00,344 - MainThread - INFO - Found existing data file 'webpath_image_data_robust.json'. Loading state...
# 2025-10-26 02:28:00,356 - MainThread - INFO - Loaded 2389 URLs. Found 2388 successful pages and 1 to retry.
# Processing Pages:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-10-26 02:28:01,855 - ThreadPoolExecutor-1_0 - ERROR - Failed to fetch https://webpath.med.utah.edu/HISTHTML/ANATOMY/anatquiz/quizaidx.htm after retries: 404 Client Error: Not Found for url: https://webpath.med.utah.edu/HISTHTML/ANATOMY/anatquiz/quizaidx.htm
# 2025-10-26 02:29:58,009 - MainThread - INFO - Crawl finished for this session. Processed 579 pages.
# 2025-10-26 02:29:58,010 - MainThread - INFO - Merging new results with 2388 previously processed pages...
# 2025-10-26 02:29:58,012 - MainThread - INFO - Found 2389 pages with relevant data or errors. Saving to webpath_image_data_robust.json...
# 2025-10-26 02:29:58,049 - MainThread - INFO - Successfully updated data file.
# --------------------------------------------------
# Total time for this session: 117.71 seconds
# Total pages with data/errors in final archive: 2389
# Data saved to: webpath_image_data_robust.json
# --------------------------------------------------
